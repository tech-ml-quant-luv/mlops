# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000") # I am telling MLflow that any experiments you are performing in this notebook, you need to track everything in this specific url

# %%
mlflow.set_experiment("Check localhost connection")
# Out:
# 2026/02/23 15:32:05 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1771840925227, experiment_id='1', last_update_time=1771840925227, lifecycle_stage='active', name='Check localhost connection', tags={}, workspace='default'>

# %%
with mlflow.start_run():
    mlflow.log_metric("Test",1)
    mlflow.log_metric("Luv",2)
# Out:
# 🏃 View run selective-bee-658 at: http://127.0.0.1:5000/#/experiments/1/runs/cabd2a64168849f49a5c18f685c9dff7
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("Test1",1)
    mlflow.log_metric("Luv1",2)
# Out:
# 🏃 View run selective-skink-739 at: http://127.0.0.1:5000/#/experiments/1/runs/c81a8bd6bc6f48d98f45de2f8555ad87
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("Test2",1)
    mlflow.log_metric("Luv2",2)
# Out:
# 🏃 View run selective-steed-562 at: http://127.0.0.1:5000/#/experiments/1/runs/b82d1bda53ac401bba504a31ee099ac6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
